# %% [markdown]
# <a href="https://colab.research.google.com/github/harshasrivaddem/Naivebayes/blob/main/naivebayes_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('cricket1 for decision tree (1).csv')
df
# Out:
#      Outlook Temperature Humidity  Windy Play Cricket
# 0      Sunny         Hot     High  False           No
# 1      Sunny         Hot     High   True           No
# 2   Overcast         Hot     High  False          Yes
# 3      Rainy        Mild     High  False          Yes
# 4      Rainy        Cool   Normal  False          Yes
# 5      Rainy        Cool   Normal   True           No
# 6   Overcast        Cool   Normal   True          Yes
# 7      Sunny        Mild     High  False           No
# 8      Sunny        Cool   Normal  False          Yes
# 9      Rainy        Mild   Normal  False          Yes
# 10     Sunny        Mild   Normal   True          Yes
# 11  Overcast        Mild     High   True          Yes
# 12  Overcast         Hot   Normal  False          Yes
# 13     Rainy        Mild     High   True           No

# %%
def outlook_to_numeric(x):
    if x== 'Rainy':
        return 0
    if x=='Overcast':
        return 1
    if x=='Sunny':
        return 2
def temp_to_numeric(x):
     if x=='Hot':
        return 0
     if x=='Mild':
        return 1
     if x=='Cool':
        return 2
def humid_to_numeric(x):
     if x=='High':
        return 0
     if x=='Normal':
        return 1
def windy_to_numeric(x):
     if x== False:
        return 0
     if x==True:
        return 1
def target_to_numeric(x):
     if x=='No':
        return 0
     if x=='Yes':
        return 1

# %%
df['OUTLOOK'] = df['Outlook'].apply(outlook_to_numeric)
df['TEMPERATURE'] = df['Temperature'].apply(temp_to_numeric)
df['HUMIDITY'] = df['Humidity'].apply (humid_to_numeric)

# %%
df['WINDY'] = df['Windy'].apply (windy_to_numeric)
df['PLAY CRICKET'] = df['Play Cricket'].apply(target_to_numeric)
df
# Out:
#      Outlook Temperature Humidity  Windy Play Cricket  OUTLOOK  TEMPERATURE  \
# 0      Sunny         Hot     High  False           No        2            0
# 1      Sunny         Hot     High   True           No        2            0
# 2   Overcast         Hot     High  False          Yes        1            0
# 3      Rainy        Mild     High  False          Yes        0            1
# 4      Rainy        Cool   Normal  False          Yes        0            2
# 5      Rainy        Cool   Normal   True           No        0            2
# 6   Overcast        Cool   Normal   True          Yes        1            2
# 7      Sunny        Mild     High  False           No        2            1
# 8      Sunny        Cool   Normal  False          Yes        2            2
# 9      Rainy        Mild   Normal  False          Yes        0            1
# 10     Sunny        Mild   Normal   True          Yes        2            1
# 11  Overcast        Mild     High   True          Yes        1            1
# 12  Overcast         Hot   Normal  False          Yes        1            0
# 13     Rainy        Mild     High   True           No        0            1
#
#     HUMIDITY  WINDY  PLAY CRICKET
# 0          0      0             0
# 1          0      1             0
# 2          0      0             1
# 3          0      0             1
# 4          1      0             1
# 5          1      1             0
# 6          1      1             1
# 7          0      0             0
# 8          1      0             1
# 9          1      0             1
# 10         1      1             1
# 11         0      1             1
# 12         1      0             1
# 13         0      1             0

# %%
x = df[['OUTLOOK', 'TEMPERATURE', 'HUMIDITY' , 'WINDY']]
y=df['PLAY CRICKET']
y
# Out:
# 0     0
# 1     0
# 2     1
# 3     1
# 4     1
# 5     0
# 6     1
# 7     0
# 8     1
# 9     1
# 10    1
# 11    1
# 12    1
# 13    0
# Name: PLAY CRICKET, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3,random_state=10)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb=GaussianNB()
gnb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(x_test)
y_pred
# Out:
# array([1, 1, 1, 1, 1], dtype=int64)

# %%
from sklearn import metrics

# %%
score=metrics.accuracy_score(y_test, y_pred)
print("Accuracy: ", score)
# Out:
# Accuracy:  0.8

# %%
gnb.score (x_test, y_test)
# Out:
# 0.8

# %%
gnb.predict([[2,2,1,0]]) #array[1] ie. Play
# Out:
# array([1], dtype=int64)

# %%
gnb.predict([[2,1,0,1]]) # array[0] i.e. Do not play
# Out:
# array([0], dtype=int64)
